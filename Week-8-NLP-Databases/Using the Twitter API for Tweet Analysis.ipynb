# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip uninstall python-twitter --yes
# Out:
# Uninstalling python-twitter-3.3:
#   Successfully uninstalled python-twitter-3.3

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x110bc90b8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2486982

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2017-07-13T17:59:00Z',
#   'created_at': '2017-07-13T17:53:13Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#Dunkirkpremiere',
#     'promoted_content': None,
#     'query': '%23Dunkirkpremiere',
#     'tweet_volume': 123204,
#     'url': 'http://twitter.com/search?q=%23Dunkirkpremiere'},
#    {'name': '#Emmys',
#     'promoted_content': None,
#     'query': '%23Emmys',
#     'tweet_volume': 62996,
#     'url': 'http://twitter.com/search?q=%23Emmys'},
#    {'name': '#NationalFrenchFryDay',
#     'promoted_content': None,
#     'query': '%23NationalFrenchFryDay',
#     'tweet_volume': 42946,
#     'url': 'http://twitter.com/search?q=%23NationalFrenchFryDay'},
#    {'name': '#SelenasNewSingleOniTunes',
#     'promoted_content': None,
#     'query': '%23SelenasNewSingleOniTunes',
#     'tweet_volume': 63737,
#     'url': 'http://twitter.com/search?q=%23SelenasNewSingleOniTunes'},
#    {'name': '#وفاه_عبدالرحمن_بن_عبدالعزيز',
#     'promoted_content': None,
#     'query': '%23%D9%88%D9%81%D8%A7%D9%87_%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D8%B1%D8%AD%D9%85%D9%86_%D8%A8%D9%86_%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D8%B9%D8%B2%D9%8A%D8%B2',
#     'tweet_volume': 38314,
#     'url': 'http://twitter.com/search?q=%23%D9%88%D9%81%D8%A7%D9%87_%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D8%B1%D8%AD%D9%85%D9%86_%D8%A8%D9%86_%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D8%B9%D8%B2%D9%8A%D8%B2'},
#    {'name': 'Liu Xiaobo',
#     'promoted_content': None,
#     'query': '%22Liu+Xiaobo%22',
#     'tweet_volume': 76735,
#     'url': 'http://twitter.com/search?q=%22Liu+Xiaobo%22'},
#    {'name': 'Pepsico',
#     'promoted_content': None,
#     'query': 'Pepsico',
#     'tweet_volume': 115646,
#     'url': 'http://twitter.com/search?q=Pepsico'},
#    {'name': 'The Leftovers',
#     'promoted_content': None,
#     'query': '%22The+Leftovers%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22The+Leftovers%22'},
#    {'name': 'Froome',
#     'promoted_content': None,
#     'query': 'Froome',
#     'tweet_volume': 30285,
#     'url': 'http://twitter.com/search?q=Froome'},
#    {'name': 'Venus Williams',
#     'promoted_content': None,
#     'query': '%22Venus+Williams%22',
#     'tweet_volume': 40255,
#     'url': 'http://twitter.com/search?q=%22Venus+Williams%22'},
#    {'name': 'Quintana',
#     'promoted_content': None,
#     'query': 'Quintana',
#     'tweet_volume': 38237,
#     'url': 'http://twitter.com/search?q=Quintana'},
#    {'name': 'Jimmy Carter',
#     'promoted_content': None,
#     'query': '%22Jimmy+Carter%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Jimmy+Carter%22'},
#    {'name': 'Sammy Sosa',
#     'promoted_content': None,
#     'query': '%22Sammy+Sosa%22',
#     'tweet_volume': 24234,
#     'url': 'http://twitter.com/search?q=%22Sammy+Sosa%22'},
#    {'name': 'San Junipero',
#     'promoted_content': None,
#     'query': '%22San+Junipero%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22San+Junipero%22'},
#    {'name': 'Kyle Walker',
#     'promoted_content': None,
#     'query': '%22Kyle+Walker%22',
#     'tweet_volume': 38235,
#     'url': 'http://twitter.com/search?q=%22Kyle+Walker%22'},
#    {'name': 'Alberto Plaza',
#     'promoted_content': None,
#     'query': '%22Alberto+Plaza%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Alberto+Plaza%22'},
#    {'name': 'Big Little Lies',
#     'promoted_content': None,
#     'query': '%22Big+Little+Lies%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Big+Little+Lies%22'},
#    {'name': 'Semedo',
#     'promoted_content': None,
#     'query': 'Semedo',
#     'tweet_volume': 18380,
#     'url': 'http://twitter.com/search?q=Semedo'},
#    {'name': 'Hugh Freeze',
#     'promoted_content': None,
#     'query': '%22Hugh+Freeze%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Hugh+Freeze%22'},
#    {'name': 'Less Than',
#     'promoted_content': None,
#     'query': '%22Less+Than%22',
#     'tweet_volume': 83446,
#     'url': 'http://twitter.com/search?q=%22Less+Than%22'},
#    {'name': 'Bonucci',
#     'promoted_content': None,
#     'query': 'Bonucci',
#     'tweet_volume': 107239,
#     'url': 'http://twitter.com/search?q=Bonucci'},
#    {'name': 'Mizgin Ay',
#     'promoted_content': None,
#     'query': '%22Mizgin+Ay%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Mizgin+Ay%22'},
#    {'name': '#DiaMundialDelRock',
#     'promoted_content': None,
#     'query': '%23DiaMundialDelRock',
#     'tweet_volume': 30887,
#     'url': 'http://twitter.com/search?q=%23DiaMundialDelRock'},
#    {'name': '#اليوم_العالمي_للبطاطس',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A_%D9%84%D9%84%D8%A8%D8%B7%D8%A7%D8%B7%D8%B3',
#     'tweet_volume': 36981,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A_%D9%84%D9%84%D8%A8%D8%B7%D8%A7%D8%B7%D8%B3'},
#    {'name': '#FelizJueves',
#     'promoted_content': None,
#     'query': '%23FelizJueves',
#     'tweet_volume': 42685,
#     'url': 'http://twitter.com/search?q=%23FelizJueves'},
#    {'name': '#SaldırGALATASARAY',
#     'promoted_content': None,
#     'query': '%23Sald%C4%B1rGALATASARAY',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Sald%C4%B1rGALATASARAY'},
#    {'name': '#انقذوا_غزه',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%86%D9%82%D8%B0%D9%88%D8%A7_%D8%BA%D8%B2%D9%87',
#     'tweet_volume': 12805,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%86%D9%82%D8%B0%D9%88%D8%A7_%D8%BA%D8%B2%D9%87'},
#    {'name': '#JustoAhoraTengoGanas',
#     'promoted_content': None,
#     'query': '%23JustoAhoraTengoGanas',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JustoAhoraTengoGanas'},
#    {'name': '#ولي_العهد_يفزع_لابن_مشعان',
#     'promoted_content': None,
#     'query': '%23%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D9%8A%D9%81%D8%B2%D8%B9_%D9%84%D8%A7%D8%A8%D9%86_%D9%85%D8%B4%D8%B9%D8%A7%D9%86',
#     'tweet_volume': 15850,
#     'url': 'http://twitter.com/search?q=%23%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D9%8A%D9%81%D8%B2%D8%B9_%D9%84%D8%A7%D8%A8%D9%86_%D9%85%D8%B4%D8%B9%D8%A7%D9%86'},
#    {'name': '#شكرا_وزاره_الاسكان',
#     'promoted_content': None,
#     'query': '%23%D8%B4%D9%83%D8%B1%D8%A7_%D9%88%D8%B2%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D8%A7%D8%B3%D9%83%D8%A7%D9%86',
#     'tweet_volume': 29797,
#     'url': 'http://twitter.com/search?q=%23%D8%B4%D9%83%D8%B1%D8%A7_%D9%88%D8%B2%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D8%A7%D8%B3%D9%83%D8%A7%D9%86'},
#    {'name': '#MyAgeInAPhrase',
#     'promoted_content': None,
#     'query': '%23MyAgeInAPhrase',
#     'tweet_volume': 14506,
#     'url': 'http://twitter.com/search?q=%23MyAgeInAPhrase'},
#    {'name': '#TrumpParis',
#     'promoted_content': None,
#     'query': '%23TrumpParis',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TrumpParis'},
#    {'name': '#SorryNotSorryOutNOW',
#     'promoted_content': None,
#     'query': '%23SorryNotSorryOutNOW',
#     'tweet_volume': 54561,
#     'url': 'http://twitter.com/search?q=%23SorryNotSorryOutNOW'},
#    {'name': '#13Jul',
#     'promoted_content': None,
#     'query': '%2313Jul',
#     'tweet_volume': 65036,
#     'url': 'http://twitter.com/search?q=%2313Jul'},
#    {'name': '#ThursdayThoughts',
#     'promoted_content': None,
#     'query': '%23ThursdayThoughts',
#     'tweet_volume': 64541,
#     'url': 'http://twitter.com/search?q=%23ThursdayThoughts'},
#    {'name': '#16JSiSiSi',
#     'promoted_content': None,
#     'query': '%2316JSiSiSi',
#     'tweet_volume': 12941,
#     'url': 'http://twitter.com/search?q=%2316JSiSiSi'},
#    {'name': '#HoyTeDigoConUnGif',
#     'promoted_content': None,
#     'query': '%23HoyTeDigoConUnGif',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HoyTeDigoConUnGif'},
#    {'name': '#EmanetinizEmanetimizdir',
#     'promoted_content': None,
#     'query': '%23EmanetinizEmanetimizdir',
#     'tweet_volume': 32337,
#     'url': 'http://twitter.com/search?q=%23EmanetinizEmanetimizdir'},
#    {'name': '#WelcomeBackDonghae',
#     'promoted_content': None,
#     'query': '%23WelcomeBackDonghae',
#     'tweet_volume': 32445,
#     'url': 'http://twitter.com/search?q=%23WelcomeBackDonghae'},
#    {'name': '#AgdYarınincirlikte',
#     'promoted_content': None,
#     'query': '%23AgdYar%C4%B1nincirlikte',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AgdYar%C4%B1nincirlikte'},
#    {'name': '#ACCKickoff',
#     'promoted_content': None,
#     'query': '%23ACCKickoff',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ACCKickoff'},
#    {'name': '#16JSíSíSí',
#     'promoted_content': None,
#     'query': '%2316JS%C3%ADS%C3%ADS%C3%AD',
#     'tweet_volume': 12939,
#     'url': 'http://twitter.com/search?q=%2316JS%C3%ADS%C3%ADS%C3%AD'},
#    {'name': '#FicoBoladoQuando',
#     'promoted_content': None,
#     'query': '%23FicoBoladoQuando',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FicoBoladoQuando'},
#    {'name': '#Eargasm4Charity',
#     'promoted_content': None,
#     'query': '%23Eargasm4Charity',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Eargasm4Charity'},
#    {'name': '#StayStrongAppie',
#     'promoted_content': None,
#     'query': '%23StayStrongAppie',
#     'tweet_volume': 35022,
#     'url': 'http://twitter.com/search?q=%23StayStrongAppie'},
#    {'name': '#DefendamosLaGratuidad',
#     'promoted_content': None,
#     'query': '%23DefendamosLaGratuidad',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DefendamosLaGratuidad'},
#    {'name': '#MbekiOnPower',
#     'promoted_content': None,
#     'query': '%23MbekiOnPower',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MbekiOnPower'},
#    {'name': '#あなたの声優さんはこの人',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%A3%B0%E5%84%AA%E3%81%95%E3%82%93%E3%81%AF%E3%81%93%E3%81%AE%E4%BA%BA',
#     'tweet_volume': 31304,
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%A3%B0%E5%84%AA%E3%81%95%E3%82%93%E3%81%AF%E3%81%93%E3%81%AE%E4%BA%BA'},
#    {'name': '#15TemmuzunÇılgınTürkleri',
#     'promoted_content': None,
#     'query': '%2315Temmuzun%C3%87%C4%B1lg%C4%B1nT%C3%BCrkleri',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2315Temmuzun%C3%87%C4%B1lg%C4%B1nT%C3%BCrkleri'},
#    {'name': '#PoshBandNames',
#     'promoted_content': None,
#     'query': '%23PoshBandNames',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PoshBandNames'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#ComicCon', 'url': 'http://twitter.com/search?q=%23ComicCon', 'promoted_content': None, 'query': '%23ComicCon', 'tweet_volume': None}, {'name': '#ESPYS', 'url': 'http://twitter.com/search?q=%23ESPYS', 'promoted_content': None, 'query': '%23ESPYS', 'tweet_volume': 214241}, {'name': '#NetNeutrality', 'url': 'http://twitter.com/search?q=%23NetNeutrality', 'promoted_content': None, 'query': '%23NetNeutrality', 'tweet_volume': 297429}, {'name': '#TeenChoice', 'url': 'http://twitter.com/search?q=%23TeenChoice', 'promoted_content': None, 'query': '%23TeenChoice', 'tweet_volume': 1393630}, {'name': 'Floyd', 'url': 'http://twitter.com/search?q=Floyd', 'promoted_content': None, 'query': 'Floyd', 'tweet_volume': 288880}, {'name': '#GetWoke', 'url': 'http://twitter.com/search?q=%23GetWoke', 'promoted_content': None, 'query': '%23GetWoke', 'tweet_volume': None}, {'name': 'Quintana', 'url': 'http://twitter.com/search?q=Quintana', 'promoted_content': None, 'query': 'Quintana', 'tweet_volume': 36501}, {'name': 'The Leftovers', 'url': 'http://twitter.com/search?q=%22The+Leftovers%22', 'promoted_content': None, 'query': '%22The+Leftovers%22', 'tweet_volume': None}, {'name': 'Sammy Sosa', 'url': 'http://twitter.com/search?q=%22Sammy+Sosa%22', 'promoted_content': None, 'query': '%22Sammy+Sosa%22', 'tweet_volume': 21977}, {'name': 'Hugh Freeze', 'url': 'http://twitter.com/search?q=%22Hugh+Freeze%22', 'promoted_content': None, 'query': '%22Hugh+Freeze%22', 'tweet_volume': None}, {'name': 'Jimmy Carter', 'url': 'http://twitter.com/search?q=%22Jimmy+Carter%22', 'promoted_content': None, 'query': '%22Jimmy+Carter%22', 'tweet_volume': None}, {'name': 'Liu Xiaobo', 'url': 'http://twitter.com/search?q=%22Liu+Xiaobo%22', 'promoted_content': None, 'query': '%22Liu+Xiaobo%22', 'tweet_volume': 73319}, {'name': 'Fresh Kid Ice', 'url': 'http://twitter.com/search?q=%22Fresh+Kid+Ice%22', 'promoted_content': None, 'query': '%22Fresh+Kid+Ice%22', 'tweet_volume': None}, {'name': 'Rick Hahn', 'url': 'http://twitter.com/search?q=%22Rick+Hahn%22', 'promoted_content': None, 'query': '%22Rick+Hahn%22', 'tweet_volume': None}, {'name': 'Modern Family', 'url': 'http://twitter.com/search?q=%22Modern+Family%22', 'promoted_content': None, 'query': '%22Modern+Family%22', 'tweet_volume': None}, {'name': 'Big Little Lies', 'url': 'http://twitter.com/search?q=%22Big+Little+Lies%22', 'promoted_content': None, 'query': '%22Big+Little+Lies%22', 'tweet_volume': None}, {'name': 'Less Than', 'url': 'http://twitter.com/search?q=%22Less+Than%22', 'promoted_content': None, 'query': '%22Less+Than%22', 'tweet_volume': 82041}, {'name': 'Venus', 'url': 'http://twitter.com/search?q=Venus', 'promoted_content': None, 'query': 'Venus', 'tweet_volume': 82334}, {'name': 'Jonathon Simmons', 'url': 'http://twitter.com/search?q=%22Jonathon+Simmons%22', 'promoted_content': None, 'query': '%22Jonathon+Simmons%22', 'tweet_volume': None}, {'name': 'Butterfield Canyon', 'url': 'http://twitter.com/search?q=%22Butterfield+Canyon%22', 'promoted_content': None, 'query': '%22Butterfield+Canyon%22', 'tweet_volume': None}, {'name': 'Loretta Lynch', 'url': 'http://twitter.com/search?q=%22Loretta+Lynch%22', 'promoted_content': None, 'query': '%22Loretta+Lynch%22', 'tweet_volume': 41173}, {'name': 'Saturday Night Live', 'url': 'http://twitter.com/search?q=%22Saturday+Night+Live%22', 'promoted_content': None, 'query': '%22Saturday+Night+Live%22', 'tweet_volume': None}, {'name': 'San Junipero', 'url': 'http://twitter.com/search?q=%22San+Junipero%22', 'promoted_content': None, 'query': '%22San+Junipero%22', 'tweet_volume': None}, {'name': 'Brandon Paul', 'url': 'http://twitter.com/search?q=%22Brandon+Paul%22', 'promoted_content': None, 'query': '%22Brandon+Paul%22', 'tweet_volume': None}, {'name': 'Bobby Petrino', 'url': 'http://twitter.com/search?q=%22Bobby+Petrino%22', 'promoted_content': None, 'query': '%22Bobby+Petrino%22', 'tweet_volume': None}, {'name': 'Michael McKean', 'url': 'http://twitter.com/sear ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:6], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#Emmys",
#     "url": "http://twitter.com/search?q=%23Emmys",
#     "promoted_content": null,
#     "query": "%23Emmys",
#     "tweet_volume": 62996
#    },
#    {
#     "name": "#NationalFrenchFryDay",
#     "url": "http://twitter.com/search?q=%23NationalFrenchFryDay",
#     "promoted_content": null,
#     "query": "%23NationalFrenchFryDay",
#     "tweet_volume": 42946
#    },
#    {
#     "name": "#ThursdayThoughts",
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "promoted_content": null,
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 64541
#    },
#    {
#     "name": "Quintana",
#     "url": "http://twitter.com/search?q=Quintana",
#     "promoted_content": null,
#     "query": "Quintana",
#     "tweet_volume": 38237
#    },
#    {
#     "name": "#MyAgeInAPhrase",
#     "url": "http://twitter.com/search?q=%23MyAgeInAPhrase",
#     "promoted_content": null,
#     "query": "%23MyAgeInAPhrase",
#     "tweet_volume": 14506
#    },
#    {
#     "name": "The Leftovers",
#     "url": "http://twitter.com/search?q=%22The+Leftovers%22",
#     "promoted_content": null,
#     "query": "%22The+Leftovers%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sammy Sosa",
#     "url": "http://twitter.com/search?q=%22Sammy+Sosa%22",
#     "promoted_content": null,
#     "query": "%22Sammy+Sosa%22",
#     "tweet_volume": 24234
#    },
#    {
#     "name": "Jimmy Carter",
#     "url": "http://twitter.com/search?q=%22Jimmy+Carter%22",
#     "promoted_content": null,
#     "query": "%22Jimmy+Carter%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Macron",
#     "url": "http://twitter.com/search?q=Macron",
#     "promoted_content": null,
#     "query": "Macron",
#     "tweet_volume": 145158
#    },
#    {
#     "name": "#ACCKickoff",
#     "url": "http://twitter.com/search?q=%23ACCKickoff",
#     "promoted_content": null,
#     "query": "%23ACCKickoff",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hugh Freeze",
#     "url": "http://twitter.com/search?q=%22Hugh+Freeze%22",
#     "promoted_content": null,
#     "query": "%22Hugh+Freeze%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Liu Xiaobo",
#     "url": "http://twitter.com/search?q=%22Liu+Xiaobo%22",
#     "promoted_content": null,
#     "query": "%22Liu+Xiaobo%22",
#     "tweet_volume": 76735
#    },
#    {
#     "name": "Fresh Kid Ice",
#     "url": "http://twitter.com/search?q=%22Fresh+Kid+Ice%22",
#     "promoted_content": null,
#     "query": "%22Fresh+Kid+Ice%22",
#     "tweet_volume": 10205
#    },
#    {
#     "name": "Rick Hahn",
#     "url": "http://twitter.com/search?q=%22Rick+Hahn%22",
#     "promoted_content": null,
#     "query": "%22Rick+Hahn%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Big Little Lies",
#     "url": "http://twitter.com/search?q=%22Big+Little+Lies%22",
#     "promoted_content": null,
#     "query": "%22Big+Little+Lies%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Less Than",
#     "url": "http://twitter.com/search?q=%22Less+Than%22",
#     "promoted_content": null,
#     "query": "%22Less+Than%22",
#     "tweet_volume": 83446
#    },
#    {
#     "name": "Venus",
#     "url": "http://twitter.com/search?q=Venus",
#     "promoted_content": null,
#     "query": "Venus",
#     "tweet_volume": 84103
#    },
#    {
#     "name": "Modern Family",
#     "url": "http://twitter.com/search?q=%22Modern+Family%22",
#     "promoted_content": null,
#     "query": "%22Modern+Family%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stranger Things",
#     "url": "http://twitter.com/search?q=%22Stranger+Things%22",
#     "promoted_content": null,
#     "query": "%22Stranger+Things%22",
#     "tweet_volume": 38013
#    },
#    {
#     "name": "Jonathon Simmons",
#     "url": "http://twitter.com/search?q=%22Jonathon+Simmons%22",
#     "promoted_content": null,
#     "query": "%22Jonathon+Simmons%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Butterfield Canyon",
#     "url": "http://twitter.com/search?q=%22Butterfield+Canyon%22",
#     "promoted_content": null,
#     "query": "%22Butterfield+Canyon%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Saturday Night Live",
#     "url": "http://twitter.com/search?q=%22Saturday+Night+Live%22",
#     "promoted_content": null,
#     "query": "%22Saturday+Night+Live%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Brandon Paul",
#     "url": "http://twitter.com/search?q=%22Brandon+Paul%22",
#     "promoted_content": null,
#     "query": "%22Brandon+Paul%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "San Junipero",
#     "url": "http://twitter.com/search?q=%22San+Junipero%22",
#     "promoted_content": null,
#     "query": "%22San+Junipero%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Michael McKean",
#     "url": "http://twitter.com/search?q=%22Michael+McKean%22",
#     "promoted_content": null,
#     "query": "%22Michael+McKean%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gus Malzahn",
#     "url": "http://twitter.com/search?q=%22Gus+Malzahn%22",
#     "promoted_content": null,
#     "query": "%22Gus+Malzahn%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bobby Petrino",
#     "url": "http://twitter.com/search?q=%22Bobby+Petrino%22",
#     "promoted_content": null,
#     "query": "%22Bobby+Petrino%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "New Senate",
#     "url": "http://twitter.com/search?q=%22New+Senate%22",
#     "promoted_content": null,
#     "query": "%22New+Senate%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "UNLV",
#     "url": "http://twitter.com/search?q=UNLV",
#     "promoted_content": null,
#     "query": "UNLV",
#     "tweet_volume": null
#    },
#    {
#     "name": "Harrison Ford",
#     "url": "http://twitter.com/search?q=%22Harrison+Ford%22",
#     "promoted_content": null,
#     "query": "%22Harrison+Ford%22",
#     "tweet_volume": 25696
#    },
#    {
#     "name": "Susan Collins",
#     "url": "http://twitter.com/search?q=%22Susan+Collins%22",
#     "promoted_content": null,
#     "query": "%22Susan+Collins%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Dunkirkpremiere",
#     "url": "http://twitter.com/search?q=%23Dunkirkpremiere",
#     "promoted_content": null,
#     "query": "%23Dunkirkpremiere",
#     "tweet_volume": 123204
#    },
#    {
#     "name": "#WeMakeNPR",
#     "url": "http://twitter.com/search?q=%23WeMakeNPR",
#     "promoted_content": null,
#     "query": "%23WeMakeNPR",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TobyAskWhyDontWe",
#     "url": "http://twitter.com/search?q=%23TobyAskWhyDontWe",
#     "promoted_content": null,
#     "query": "%23TobyAskWhyDontWe",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Westworld",
#     "url": "http://twitter.com/search?q=%23Westworld",
#     "promoted_content": null,
#     "query": "%23Westworld",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JumpedInAndShouted",
#     "url": "http://twitter.com/search?q=%23JumpedInAndShouted",
#     "promoted_content": null,
#     "query": "%23JumpedInAndShouted",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PHLResist",
#     "url": "http://twitter.com/search?q=%23PHLResist",
#     "promoted_content": null,
#     "query": "%23PHLResist",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EmbraceyourGeeknessDay",
#     "url": "http://twitter.com/search?q=%23EmbraceyourGeeknessDay",
#     "promoted_content": null,
#     "query": "%23EmbraceyourGeeknessDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TwitterSmarter",
#     "url": "http://twitter.com/search?q=%23TwitterSmarter",
#     "promoted_content": null,
#     "query": "%23TwitterSmarter",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheZoneCast",
#     "url": "http://twitter.com/search?q=%23TheZoneCast",
#     "promoted_content": null,
#     "query": "%23TheZoneCast",
#     "tweet_volume": null
#    },
#    {
#     "name": "#713Day",
#     "url": "http://twitter.com/search?q=%23713Day",
#     "promoted_content": null,
#     "query": "%23713Day",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JDCK17",
#     "url": "http://twitter.com/search?q=%23JDCK17",
#     "promoted_content": null,
#     "query": "%23JDCK17",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SelenasNewSingleOniTunes",
#     "url": "http://twitter.com/search?q=%23SelenasNewSingleOniTunes",
#     "promoted_content": null,
#     "query": "%23SelenasNewSingleOniTunes",
#     "tweet_volume": 63737
#    }
#   ],
#   "as_of": "2017-07-13T17:59:00Z",
#   "created_at": "2017-07-13T17:53:13Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['St. Louis'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','St. Louis']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #MyAgeInAPhrase,#NationalFrenchFryDay,#ThursdayThoughts,Mizgin Ay,#Emmys,#SelenasNewSingleOniTunes,#Dunkirkpremiere,#FicoBoladoQuando,#FelizJueves,#あなたの声優さんはこの人,#TrumpParis,#وفاه_عبدالرحمن_بن_عبدالعزيز,Sammy Sosa,Less Than,San Junipero,#MbekiOnPower,#EmanetinizEmanetimizdir,#StayStrongAppie,Liu Xiaobo,#16JSiSiSi,#DefendamosLaGratuidad,#انقذوا_غزه,Quintana,#ولي_العهد_يفزع_لابن_مشعان,#ACCKickoff,#SorryNotSorryOutNOW,#13Jul,#SaldırGALATASARAY,#WelcomeBackDonghae,The Leftovers,Jimmy Carter,#HoyTeDigoConUnGif,Pepsico,Venus Williams,Froome,#شكرا_وزاره_الاسكان,#JustoAhoraTengoGanas,#PoshBandNames,#DiaMundialDelRock,#اليوم_العالمي_للبطاطس,Bonucci,#Eargasm4Charity,Kyle Walker,#AgdYarınincirlikte,Alberto Plaza,#16JSíSíSí,Semedo,#15TemmuzunÇılgınTürkleri,Big Little Lies,Hugh Freeze
# ('----------', 'us')
# #MyAgeInAPhrase,#EmbraceyourGeeknessDay,#NationalFrenchFryDay,#ThursdayThoughts,#Emmys,Fresh Kid Ice,Venus,#SelenasNewSingleOniTunes,#Dunkirkpremiere,Macron,Bobby Petrino,Susan Collins,Stranger Things,Harrison Ford,#TheZoneCast,Sammy Sosa,Less Than,San Junipero,New Senate,Liu Xiaobo,Rick Hahn,Saturday Night Live,Quintana,#ACCKickoff,UNLV,Modern Family,#JumpedInAndShouted,#TwitterSmarter,The Leftovers,Jonathon Simmons,Jimmy Carter,Butterfield Canyon,#Westworld,#WeMakeNPR,Michael McKean,Gus Malzahn,#PHLResist,#TobyAskWhyDontWe,Brandon Paul,#JDCK17,#713Day,Big Little Lies,Hugh Freeze
# ('----------', 'St. Louis')
# #BBLF,#MyAgeInAPhrase,#EmbraceyourGeeknessDay,#NationalFrenchFryDay,#ThursdayThoughts,#Emmys,Fresh Kid Ice,Venus,#SelenasNewSingleOniTunes,#Dunkirkpremiere,Macron,Bobby Petrino,Susan Collins,Stranger Things,Harrison Ford,#TheZoneCast,Sammy Sosa,Less Than,San Junipero,New Senate,Liu Xiaobo,Saturday Night Live,Rick Hahn,Quintana,#ACCKickoff,UNLV,Modern Family,#JumpedInAndShouted,#TwitterSmarter,The Leftovers,Jonathon Simmons,Jimmy Carter,Butterfield Canyon,#Westworld,#WeMakeNPR,Michael McKean,Gus Malzahn,#PHLResist,#TobyAskWhyDontWe,Brandon Paul,#JDCK17,#713Day,Big Little Lies,Hugh Freeze

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and st-louis'))
print((trends_set['St. Louis'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#ACCKickoff', '#MyAgeInAPhrase', '#NationalFrenchFryDay', '#ThursdayThoughts', 'Sammy Sosa', '#Emmys', 'Less Than', 'The Leftovers', '#SelenasNewSingleOniTunes', 'San Junipero', 'Jimmy Carter', '#Dunkirkpremiere', 'Liu Xiaobo', 'Quintana', 'Big Little Lies', 'Hugh Freeze'}
# ('==========', 'intersection of us and st-louis')
# {'#MyAgeInAPhrase', '#EmbraceyourGeeknessDay', '#NationalFrenchFryDay', '#ThursdayThoughts', '#Emmys', 'Fresh Kid Ice', 'Venus', '#SelenasNewSingleOniTunes', '#Dunkirkpremiere', 'Macron', 'Bobby Petrino', 'Susan Collins', 'Stranger Things', 'Harrison Ford', '#TheZoneCast', 'Sammy Sosa', 'Less Than', 'San Junipero', 'New Senate', 'Liu Xiaobo', 'Rick Hahn', 'Saturday Night Live', 'Quintana', '#ACCKickoff', 'UNLV', 'Modern Family', '#JumpedInAndShouted', '#TwitterSmarter', 'The Leftovers', 'Jonathon Simmons', 'Jimmy Carter', 'Butterfield Canyon', '#Westworld', '#WeMakeNPR', 'Michael McKean', 'Gus Malzahn', '#PHLResist', '#TobyAskWhyDontWe', 'Brandon Paul', '#JDCK17', '#713Day', 'Big Little Lies', 'Hugh Freeze'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = 'Liu Xiaobo' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Thu Jul 13 19:47:47 +0000 2017', 'id': 885586575215734785, 'id_str': '885586575215734785', 'text': "RT @BretStephensNYT: Every thoughtful person should take 10 minutes to read Liu's final statement, later his (in absentia) Nobel lecture. h…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BretStephensNYT', 'name': 'Bret Stephens', 'id': 1428659995, 'id_str': '1428659995', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 831155382894608385, 'id_str': '831155382894608385', 'name': 'Thomas PB Becker🇪🇺', 'screen_name': 'TomPaBB', 'location': 'Gaia in Iunio', 'description': 'Wechselwähler.Nicht die hellste Kerze auf der Torte. Troll des lieben Gottes.\nG 9.🇪🇺💗🇬🇧 Klare Tendenz zur Demenz. Gefällt\u200b mir=Interesse.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 43, 'friends_count': 132, 'listed_count': 4, 'created_at': 'Mon Feb 13 14:57:40 +0000 2017', 'favourites_count': 5624, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 5512, 'lang': 'de', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/840676565960790016/XpUL04i6_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/840676565960790016/XpUL04i6_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/831155382894608385/1491489285', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Jul 13 16:59:29 +0000 2017', 'id': 885544222497136641, 'id_str': '885544222497136641', 'text': "Every thoughtful person should take 10 minutes to read Liu's final statement, later his (in absentia) Nobel lecture. https://t.co/NfmXwU1u5N", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/NfmXwU1u5N', 'expanded_url': 'https://www.nobelprize.org/nobel_prizes/peace/laureates/2010/xiaobo-lecture.html', 'display_url': 'nobelprize.org/nobel_prizes/p…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1428659995, 'id_str': '1428659995', 'name': 'Bret Stephens', 'screen_name': 'BretStephensNYT', 'location': 'New York City', 'description': 'Op-ed columnist, New York Times. Formerly WSJ, JPost. Chilango. "The nambiest and the pambiest," Dinesh D\'Souza. Married to a better writer. Dad to K, N & L.', 'url': 'https://t.co/UmqCI5RSM5', 'entities': {'url': {'urls': [{'url': 'https://t.co/UmqCI5RSM5', 'expanded_url': 'http://www.nytimes.com', 'display_url': 'nytimes.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 83034, 'friends_count': 465, 'listed_count': 1832, 'created_at': 'Tue May 14 19:1 ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 75

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ["RT @BretStephensNYT: Every thoughtful person should take 10 minutes to read Liu's final statement, later his (in absentia) Nobel lecture. h…",
#  'RT @amnestyfrance: Continuons le combat de Liu Xiaobo ! https://t.co/dQddtkn82U',
#  'RT @jennyhan: "Freedom of expression is the basis of human rights, the source of humanity and the mother of truth." -- Liu Xiaobo https://t…',
#  'RT @guardian: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'RT @lemondefr: Mort de Liu Xiaobo, écrivain et dissident chinois, Prix Nobel de la paix 2010 https://t.co/GX4E3bAEVy',
#  'RT @ingridbbalabu: A Liu Xiaobo lo mató el régimen comunista chino al negarle tratamiento médico. En pocas palabras, fue asesinado. https:/…',
#  'RT @repubblica: Liu Xiaobo, premio Nobel per la pace, nella nostra foto di copertina. Il dissidente cinese si è spento a 61 anni https://t.…',
#  'RT @DMatamala: Día de luto para la libertad: murió el Nobel Liu Xiaobo. \nY poco$ gobierno$ $e atreven a condenar a la dictadura comuni$ta c…',
#  "RT @amnestyusa: RT this to stand in solidarity with Liu Xiaobo's wife Liu Xia &amp; his family, who have suffered an immeasurable loss. https:/…",
#  'RT @ElFinanciero_Mx: Fallece el disidente chino y Nobel de la Paz, Liu Xiaobo https://t.co/pVYBJ2ALqf https://t.co/zAFrJwYKjE',
#  'RT @guardianworld: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/RTuLaNne1b',
#  'RT @edgarmorinparis: Mort de Liu Xiaobo, l\'homme qui n\'avait "pas d’ennemis, pas de haine"',
#  'RT @tedcruz: Today, the world lost a hero of liberty and freedom -- Liu Xiaobo: https://t.co/cY6jvqWfws',
#  "RT @TIME: Liu Xiaobo, China's most prominent political prisoner, dies at 61 https://t.co/BeYm6o89iO",
#  'RT @PekingMike: Some day, if the arc of the moral universe resumes a path toward justice, Liu will be honored &amp; remembered in China https:/…',
#  'RT @ElInformadorVE: Murió el nobel de la Paz chino Liu Xiaobo - https://t.co/icRYT6ZKac https://t.co/3RV4tTVXtC',
#  'RT @BillKristol: Hours after Liu Xiaobo dies after denied chance for treatment abroad, Trump calls Xi "a great leader, very talented man" &amp;…',
#  'RT @elpais_america: Muere el Nobel de la Paz y disidente Liu Xiaobo, tras 11 años de cárcel en China https://t.co/SkmCM40k9G',
#  'RT @DiarioTalCual: Muere Liu Xiaobo, el Nobel de la Paz preso por pedir reformas democráticas a China. https://t.co/kiC3TEpmN0 https://t.co…',
#  'RT @JohnRalstonSaul: After the tragic death of Liu Xiaobo, here are a few thoughts: https://t.co/pevPxtN9N7',
#  'RT @Snowden: Xiaobo died under guard in a world where states still dim our brightest lights. The law is not justice. 愿我们的兄弟休息。 https://t.co…',
#  'Políticos e grupos de direitos humanos lamentaram a morte do Nobel da Paz Liu Xiaobo https://t.co/s3O0uvsXu4',
#  'RT @AP: Imprisoned for all 7 years since he was awarded the Nobel Peace Prize, Chinese political prisoner Liu Xiaobo dies. https://t.co/ZXQ…',
#  'RT @Snowden: Xiaobo died under guard in a world where states still dim our brightest lights. The law is not justice. 愿我们的兄弟休息。 https://t.co…',
#  'RT @AP: Imprisoned for all 7 years since he was awarded the Nobel Peace Prize, Chinese political prisoner Liu Xiaobo dies. https://t.co/ZXQ…',
#  'RT @iptuttle: "Liu Xiaobo was, in a sense, the leader of China." @NRO\'s editors: https://t.co/tQdZgl6DrW',
#  'RT @amnestynl: Zelfs een strafkamp kreeg Nobelprijswinnaar Liu Xiaobo er niet onder: hij bleef vechten https://t.co/GPSX7bwqN3 via @volkskr…',
#  'RT @repubblica: Cina, addio a Liu Xiaobo eroe di Tienanmen e Nobel per la Pace: le immagini https://t.co/oiT1Lb6piL',
#  'Liu Xiaobo, Nobel laureate and Chinese political prisoner, dies aged 61\n\nhttps://t.co/wuzRMnHxxx',
#  'RT @EmmanuelMacron: Hommage à Liu Xiaobo, prix Nobel de la paix, grand combattant de la liberté. Pensées et soutien à ses proches et son ép…',
#  "Liu Xiaobo 'will be remembered as a symbol of democracy' https://t.co/LNqOBic4cr",
#  "Liu Xiaobo: China's most prominent dissident dies https://t.co/3W2VaVgovS",
#  'RT @EmmanuelMacron: Hommage à Liu Xiaobo, prix Nobel de la paix, grand combattant de la liberté. Pensées et soutien à ses proches et son ép…',
#  'RT @TheEconomist: The Communist Party wants the world to forget Liu Xiaobo and what he stood for. There is a danger that it will https://t.…',
#  'RT @EmmanuelMacron: Hommage à Liu Xiaobo, prix Nobel de la paix, grand combattant de la liberté. Pensées et soutien à ses proches et son ép…',
#  'RT @BBCBreaking: Chinese Nobel laureate Liu Xiaobo, jailed for his pro-democracy work, dies in hospital aged 61, officials say https://t.co…',
#  'RT @TheEconomist: Liu Xiaobo, who died today, was a resolute advocate of democracy and showed extraordinary courage. Our cover: https://t.c…',
#  '"Liu Xiaobo będzie nadal inspirował obrońców praw człowieka" https://t.co/T6CW6SpEWF',
#  'RT @DiarioTalCual: Muere Liu Xiaobo, el Nobel de la Paz preso por pedir reformas democráticas a China. https://t.co/kiC3TEpmN0 https://t.co…',
#  "Liu Xiaobo, China's Most Prominent Political Prisoner, Dies at 61 via /r/worldnews https://t.co/5D7VNEcjQY",
#  'RT @guardian: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'RT @guardian: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'En la muerte del disidente chino, galardonado con el Nobel, reproducimos algunas de las claves de su pensamiento.\xa0 https://t.co/7C20B8XtUJ',
#  'RT @DMatamala: Día de luto para la libertad: murió el Nobel Liu Xiaobo. \nY poco$ gobierno$ $e atreven a condenar a la dictadura comuni$ta c…',
#  'Zemřel #LiuXiaobo, vězněný disident a neúnavný bojovník za svobodu a lidskost, odmítající represe čínského režimu.… https://t.co/R90j1L2ql7',
#  'RT @nicole_hong: My dad sent me this poem after Liu Xiaobo\'s death. \n\n"You want to bury him / bury into the dirt / but you forget / he is a…',
#  'RT @BillKristol: Hours after Liu Xiaobo dies after denied chance for treatment abroad, Trump calls Xi "a great leader, very talented man" &amp;…',
#  "FT: Liu Xiaobo 'will be remembered as a symbol of democracy' https://t.co/JinPSi1t9p",
#  'RT @ONU_es: La ONU lamenta la muerte del Premio Nobel de la Paz Liu Xiaobo, un referente para la democracia https://t.co/DBycFh1FFM #China…',
#  'RT @XHNews: China urges relevant countries to respect its judicial sovereignty, not to meddle in its domestic affairs with Liu Xiaobo case',
#  "China siente culpa por muerte ''prematura'' de disidente Liu Xiaobo - economiahoy.mx https://t.co/vg0xNuCemM https://t.co/CwVfPXasa0",
#  'RT @amnistiaespana: Hoy lloramos al inmenso Liu Xiaobo, defensor de derechos humanos. Su lucha #valiente inspiró a millones de personas en…',
#  'RT @rafael_ciprian: Muere el Premio Nobel chino Liu Xiaobo, el último mártir de la matanza de Tiananmen https://t.co/g3o3lyyGZi vía @acento…',
#  'RT @driesvangorkum: LIU XIAOBO, Nobelprijswinnaar Vrede, 2010, overleed heden aan Kanker in gevangenschap in China.',
#  "RT @JNBPage: China's Liu Xiaobo was the first Nobel Peace laureate to die in custody since Nazi Germany in 1938. Our obituary: https://t.co…",
#  'Macron rend hommage à Liu Xiaobo https://t.co/aX3CobOLde via @Le_Figaro',
#  'RT @DerSPIEGEL: Chinesischer Dissident: Liu Xiaobo ist tot https://t.co/hfsMt1TMD8 https://t.co/jzxkhu5j1D',
#  'RT @guardian: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'RT @AJEnglish: Liu Xiaobo spent almost a quarter of his life behind bars in China for advocating human rights and democracy. https://t.co/E…',
#  '"劉曉波先生訃告 Obituary For Mr. Liu Xiaobo | 公民行動影音紀錄資料庫" ( https://t.co/82kMLAMaS2 )',
#  "Liu Xiaobo: China's most prominent dissident dies - BBC News https://t.co/yM3CmeXO0C",
#  "RT @FT: Liu Xiaobo 'will be remembered as a symbol of democracy' https://t.co/q6BuqIMO9N",
#  'RT @DMatamala: Día de luto para la libertad: murió el Nobel Liu Xiaobo. \nY poco$ gobierno$ $e atreven a condenar a la dictadura comuni$ta c…',
#  'RT @AsiaSocietyNY: South China Morning Post editor-in-chief: Liu Xiaobo death is a "tragedy," expects protests in Hong Kong\n#AsiaSocietyLIVE',
#  'RT @guardian: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'RT @AP: Imprisoned for all 7 years since he was awarded the Nobel Peace Prize, Chinese political prisoner Liu Xiaobo dies. https://t.co/ZXQ…',
#  'RT @guardiannews: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/fLoXcKZKN0',
#  'RT @UNHumanRights: Death of Liu Xiaobo: He "was &amp; will continue to be an inspiration for all human rights defenders" - #Zeid https://t.co/E…',
#  'RT @guardian: Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'RT @amnistiaespana: Hoy lloramos al inmenso Liu Xiaobo, defensor de derechos humanos. Su lucha #valiente inspiró a millones de personas en…',
#  "RT @AP: Officials say China's most prominent political prisoner, Nobel Peace Prize laureate Liu Xiaobo, has died at 61. https://t.co/NxVoZq…",
#  'RT @BBCBreaking: "The man China couldn\'t erase" - a look back at the life of Nobel laureate and human rights advocate Liu Xiaobo \n\nhttps://…',
#  'Fallece el Premio Nobel de la Paz, Liu Xiaobo, luego de estar preso en #China https://t.co/CRUzcZf2Be https://t.co/Azw4MO4yrr',
#  'Mehr von solchen Menschen wie Liu #Xiaobo, die kompromisslos und friedlich für die Freiheit kämpfen! #China https://t.co/6XkrZ2KSDY',
#  'RT @AP: BREAKING: Chinese judicial bureau says jailed Nobel Peace Prize laureate Liu Xiaobo has died of multiple organ failure. He was 61.',
#  'RT @DiarioTalCual: Muere Liu Xiaobo, el Nobel de la Paz preso por pedir reformas democráticas a China. https://t.co/kiC3TEpmN0 https://t.co…',
#  'A mighty totara has fallen. Chinese dissident Liu Xiaobo dies https://t.co/6HSUVBnWOK @AmnestyNZ',
#  'RT @SFTHQ: deeply saddened to hear Liu Xiaobo, Nobel Peace Prize winner &amp; an unwavering champion 4 human rights &amp;freedom for all oppressed…',
#  'RT @nicole_hong: My dad sent me this poem after Liu Xiaobo\'s death. \n\n"You want to bury him / bury into the dirt / but you forget / he is a…',
#  'RT @BretStephensNYT: Memo to China boosters: A country that murders its best people will never be great. God bless Liu Xiaobo. (BLS) https:…',
#  'RT @ajplus: Liu Xiaobo has died at age 61. Diagnosed with liver cancer, the Nobel Peace Prize laureate spent 11 years in jail in China. htt…',
#  'RT @Snowden: Xiaobo died under guard in a world where states still dim our brightest lights. The law is not justice. 愿我们的兄弟休息。 https://t.co…',
#  "RT @Arab_News: China's Nobel laureate Liu Xiaobo dies aged 61. https://t.co/Q8RHwU7XJg",
#  "RT @AP: Officials say China's most prominent political prisoner, Nobel Peace Prize laureate Liu Xiaobo, has died at 61. https://t.co/NxVoZq…",
#  'Overnight on Twitter, 100s of PRC nationals and other users of simplified Chinese praised @iingwen as a true leader for honoring Liu Xiaobo.',
#  'RT @nivincent: A very detailed and heartbreaking obit by @ChuBailiang  https://t.co/jpSRF2OKHv',
#  'Chinese dinsidest and Nobel laureate Liu Xoaobi dies – video https://t.co/L6qrHDiO0Z',
#  'Chinese dissident and Nobel laureate Liu Xiaobo dies – video https://t.co/FRnHry8DoP',
#  'RT @AJEnglish: Liu Xiaobo spent almost a quarter of his life behind bars in China for advocating human rights and democracy. https://t.co/E…',
#  'RT @AP: Imprisoned for all 7 years since he was awarded the Nobel Peace Prize, Chinese political prisoner Liu Xiaobo dies. https://t.co/ZXQ…',
#  "RT @xeniavanza: Rights Groups, Nobel Commission Express Regret Over Liu's Death https://t.co/Iuer2BnlBw",
#  'RT @AlertaNews24: 1600 GMT, TITULARES:\n\n🇻🇳Muere Nobel Liu Xiaobo\n🇧🇷 Lula da Silva va a prisión\n🇵🇪 Se espera condena de Humala\n🇺🇸 Trump de v…',
#  'RT @AP: Imprisoned for all 7 years since he was awarded the Nobel Peace Prize, Chinese political prisoner Liu Xiaobo dies. https://t.co/ZXQ…',
#  'RT @UNHumanRights: Death of Liu Xiaobo: He "was &amp; will continue to be an inspiration for all human rights defenders" - #Zeid https://t.co/E…',
#  'Amor con dificultades: el romance entre el fallecido Nobel de Paz y disidente chino Liu Xiaobo y su esposa, la poe… https://t.co/6ctJRVxTPu',
#  'Liu Xiaobo obituary https://t.co/T8Esd00i7f',
#  'El dolor de sus compatriotas https://t.co/NFejgIP6p7 vía @libertaddigital',
#  'RT @tedcruz: Today, the world lost a hero of liberty and freedom -- Liu Xiaobo: https://t.co/cY6jvqWfws',
#  'RT @VOAChinese: 国际特赦：刘晓波是给中国和世界留下永久遗产的人权巨人\nhttps://t.co/uSjbMnMlt6',
#  'RT @EmmanuelMacron: Hommage à Liu Xiaobo, prix Nobel de la paix, grand combattant de la liberté. Pensées et soutien à ses proches et son ép…']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Thu Jul 13 19:47:47 +0000 2017",
#  "id": 885586575215734785,
#  "id_str": "885586575215734785",
#  "text": "RT @BretStephensNYT: Every thoughtful person should take 10 minutes to read Liu's final statement, later his (in absentia) Nobel lecture. h\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "BretStephensNYT",
#     "name": "Bret Stephens",
#     "id": 1428659995,
#     "id_str": "1428659995",
#     "indices": [
#      3,
#      19
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 831155382894608385,
#   "id_str": "831155382894608385",
#   "name": "Thomas PB Becker\ud83c\uddea\ud83c\uddfa",
#   "screen_name": "TomPaBB",
#   "location": "Gaia in Iunio",
#   "description": "Wechselw\u00e4hler.Nicht die hellste Kerze auf der Torte. Troll des lieben Gottes.\nG 9.\ud83c\uddea\ud83c\uddfa\ud83d\udc97\ud83c\uddec\ud83c\udde7 Klare Tendenz zur Demenz. Gef\u00e4llt\u200b mir=Interesse.",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 43,
#   "friends_count": 132,
#   "listed_count": 4,
#   "created_at": "Mon Feb 13 14:57:40 +0000 2017",
#   "favourites_count": 5624,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 5512,
#   "lang": "de",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/840676565960790016/XpUL04i6_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/840676565960790016/XpUL04i6_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/831155382894608385/1491489285",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Thu Jul 13 16:59:29 +0000 2017",
#   "id": 885544222497136641,
#   "id_str": "885544222497136641",
#   "text": "Every thoughtful person should take 10 minutes to read Liu's final statement, later his (in absentia) Nobel lecture. https://t.co/NfmXwU1u5N",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/NfmXwU1u5N",
#      "expanded_url": "https://www.nobelprize.org/nobel_prizes/peace/laureates/2010/xiaobo-lecture.html",
#      "display_url": "nobelprize.org/nobel_prizes/p\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1428659995,
#    "id_str": "1428659995",
#    "name": "Bret Stephens",
#    "screen_name": "BretStephensNYT",
#    "location": "New York City",
#    "description": "Op-ed columnist, New York Times. Formerly WSJ, JPost. Chilango. \"The nambiest and the pambiest,\" Dinesh D'Souza. Married to a better writer. Dad to K, N & L.",
#    "url": "https://t.co/UmqCI5RSM5",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/UmqCI5RSM5",
#        "expanded_url": "http://www.nytimes.com",
#        "display_url": "nytimes.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 83034,
#    "friends_count": 465,
#    "listed_count": 1832,
#    "created_at": "Tue May 14 19:18:55 +0000 2013",
#    "favourites_count": 31,
#    "utc_offset": -25200,
#    "time_zone": "Pacific Time (US & Canada)",
#    "geo_enabled": false,
#    "verified": true,
#    "statuses_count": 2025,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/737577667340312577/ySzcskV-_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/737577667340312577/ySzcskV-_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1428659995/1498513242",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 56,
#   "favorite_count": 105,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 56,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 56
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...
https://t.co/UnoizJRx8D%22,
print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
#   File "<ipython-input-52-b2c35e228163>", line 2
#     https://t.co/UnoizJRx8D%22,
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('Liu', 65), ('RT', 54), ('Xiaobo', 37), ('Nobel', 31), ('de', 28), ('a', 24), ('of', 18), ('Xiaobo,', 18), ('la', 18), ('the', 14)]
#
# [('AP', 3), ('BretStephensNYT', 2), ('repubblica', 2), ('TheEconomist', 2), ('BBCBreaking', 2), ('amnestyfrance', 1), ('jennyhan', 1), ('guardian', 1), ('lemondefr', 1), ('ingridbbalabu', 1)]
#
# [('China', 3), ('LiuXiaobo', 1), ('valiente', 1), ('AsiaSocietyLIVE', 1), ('Zeid', 1), ('Xiaobo', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# Liu                  |     65
# RT                   |     54
# Xiaobo               |     37
# Nobel                |     31
# de                   |     28
# a                    |     24
# of                   |     18
# Xiaobo,              |     18
# la                   |     18
# the                  |     14
#
#     Screen Name      | Count
# ****************************************
# AP                   |      3
# BretStephensNYT      |      2
# repubblica           |      2
# TheEconomist         |      2
# BBCBreaking          |      2
# amnestyfrance        |      1
# jennyhan             |      1
# guardian             |      1
# lemondefr            |      1
# ingridbbalabu        |      1
#
#       Hashtag        | Count
# ****************************************
# China                |      3
# LiuXiaobo            |      1
# valiente             |      1
# AsiaSocietyLIVE      |      1
# Zeid                 |      1
# Xiaobo               |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  2886   |   BBCBreaking   | RT @BBCBreaking: Chinese Nobel laureate Liu Xiaobo
#         |                 | , jailed for his pro-democracy work, dies in hospi
#         |                 | tal aged 61, officials say https://t.co…
#  2203   |   BBCBreaking   | RT @BBCBreaking: "The man China couldn't erase" -
#         |                 | a look back at the life of Nobel laureate and huma
#         |                 | n rights advocate Liu Xiaobo \\https://…
#  1298   |     Snowden     | RT @Snowden: Xiaobo died under guard in a world wh
#         |                 | ere states still dim our brightest lights. The law
#         |                 |  is not justice. 愿我们的兄弟休息。 https://t.co…
#  1003   |       AP        | RT @AP: BREAKING: Chinese judicial bureau says jai
#         |                 | led Nobel Peace Prize laureate Liu Xiaobo has died
#         |                 |  of multiple organ failure. He was 61.
#   740   |   nicole_hong   | RT @nicole_hong: My dad sent me this poem after Li
#         |                 | u Xiaobo's death. \\"You want to bury him / bury i
#         |                 | nto the dirt / but you forget / he is a…
#   657   | EmmanuelMacron  | RT @EmmanuelMacron: Hommage à Liu Xiaobo, prix Nob
#         |                 | el de la paix, grand combattant de la liberté. Pen
#         |                 | sées et soutien à ses proches et son ép…
#   379   |   amnestyusa    | RT @amnestyusa: RT this to stand in solidarity wit
#         |                 | h Liu Xiaobo's wife Liu Xia &amp; his family, who
#         |                 | have suffered an immeasurable loss. https:/…
#   359   | amnistiaespana  | RT @amnistiaespana: Hoy lloramos al inmenso Liu Xi
#         |                 | aobo, defensor de derechos humanos. Su lucha #vali
#         |                 | ente inspiró a millones de personas en…
#   274   |       AP        | RT @AP: Officials say China's most prominent polit
#         |                 | ical prisoner, Nobel Peace Prize laureate Liu Xiao
#         |                 | bo, has died at 61. https://t.co/NxVoZq…
#   272   |  TheEconomist   | RT @TheEconomist: Liu Xiaobo, who died today, was
#         |                 | a resolute advocate of democracy and showed extrao
#         |                 | rdinary courage. Our cover: https://t.c…
